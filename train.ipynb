# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data='data.yaml',epochs=25, patience=10, seed=25, device='cpu')
# Out:
# New https://pypi.org/project/ultralytics/8.0.207 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.206  Python-3.9.13 torch-2.1.0+cu121 CPU (Intel Core(TM) i5-9300H 2.40GHz)
# ...

# %%
results = model.val()
# Out:
# Ultralytics YOLOv8.0.206  Python-3.9.13 torch-2.1.0+cu121 CPU (Intel Core(TM) i5-9300H 2.40GHz)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\machine_learning\orderstack\dataset\labels.cache... 117 images, 0 backgrounds, 0 corrupt: 100%|██████████| 117/117 [00:00<?, ?it/s]
# train: WARNING  D:\machine_learning\orderstack\dataset\images\batch33_d1d0b952-b248-4542-8dcf-9bdea78a5b25_1.jpg: 2 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:25<00:00,  3.23s/it]
#                    all        117       1751      0.871      0.895      0.947      0.737
#                  table        117       1500       0.86      0.834      0.931      0.656
#                 header        117        122      0.786      0.852      0.914      0.635
#                 column        117        129      0.969          1      0.995      0.921
# ...

# %%
model.export()
# Out:
# Ultralytics YOLOv8.0.206  Python-3.9.13 torch-2.1.0+cu121 CPU (Intel Core(TM) i5-9300H 2.40GHz)
#
# PyTorch: starting from 'runs\detect\train8\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (5.9 MB)
#
# TorchScript: starting export with torch 2.1.0+cu121...
# TorchScript: export success  2.4s, saved as 'runs\detect\train8\weights\best.torchscript' (11.9 MB)
#
# Export complete (4.4s)
# Results saved to D:\machine_learning\orderstack\runs\detect\train8\weights
# Predict:         yolo predict task=detect model=runs\detect\train8\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train8\weights\best.torchscript imgsz=640 data=data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\train8\\weights\\best.torchscript'

# %% [markdown]
# ### Training better model with augmentation

# %%
model2 = YOLO('yolov8n.pt')

# %%
results2 = model2.train(data='data_2.yaml',epochs=25, patience=10, seed=25, device='cpu')
# Out:
# Ultralytics YOLOv8.0.206  Python-3.9.13 torch-2.1.0+cu121 CPU (Intel Core(TM) i5-9300H 2.40GHz)
# ...

# %%
model2.export()
# Out:
# Ultralytics YOLOv8.0.206  Python-3.9.13 torch-2.1.0+cu121 CPU (Intel Core(TM) i5-9300H 2.40GHz)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs\detect\train10\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (5.9 MB)
#
# TorchScript: starting export with torch 2.1.0+cu121...
# TorchScript: export success  2.3s, saved as 'runs\detect\train10\weights\best.torchscript' (11.9 MB)
#
# Export complete (4.4s)
# Results saved to D:\machine_learning\orderstack\runs\detect\train10\weights
# Predict:         yolo predict task=detect model=runs\detect\train10\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train10\weights\best.torchscript imgsz=640 data=data_2.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\train10\\weights\\best.torchscript'

# %%
model2.predict('test.jpg')
# Out:
# image 1/1 d:\machine_learning\orderstack\test.jpg: 640x480 7 columns, 1 header, 1 table, 619.5ms
# Speed: 26.7ms preprocess, 619.5ms inference, 27.0ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'column', 1: 'header', 2: 'table'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
# ...
